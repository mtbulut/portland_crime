# %%
import pandas as pd

# %%
import os

# %%
path = os.path.join("Unsolved/Resources", "crime_incident_data2017.csv")

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#                             Address  Case Number Crime Against  \
# 0                               NaN  17-X4762181        Person
# 1                               NaN  17-X4757824      Property
# 2          200 BLOCK OF SE 78TH AVE    17-900367      Property
# 3                               NaN  17-X4748982      Property
# 4                               NaN  17-X4748982      Property
# ...                             ...          ...           ...
# 41027   8800 BLOCK OF NE SANDY BLVD    17-285386       Society
# 41028     9700 BLOCK OF SE STARK ST    17-286082       Society
# 41029     9700 BLOCK OF SE STARK ST    17-286413       Society
# 41030               UNKNOWN ADDRESS    17-286445       Society
# 41031  8000 BLOCK OF SE POWELL BLVD    17-286659       Society
#
#           Neighborhood  Number of Records Occur Date Occur Month Year  \
# 0                  NaN                  1     1/1/96           1/1/96
# ...

# %%
df.head()
# Out:
#                     Address  Case Number Crime Against     Neighborhood  \
# 0                       NaN  17-X4762181        Person              NaN
# 1                       NaN  17-X4757824      Property       Centennial
# 2  200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                       NaN  17-X4748982      Property  Southwest Hills
# 4                       NaN  17-X4748982      Property  Southwest Hills
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
#
#    Offense Category  Offense Count                             Offense Type  \
# 0      Sex Offenses              1                                     Rape
# ...

# %%
df.head(6)
# Out:
#                         Address  Case Number Crime Against     Neighborhood  \
# 0                           NaN  17-X4762181        Person              NaN
# 1                           NaN  17-X4757824      Property       Centennial
# 2      200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                           NaN  17-X4748982      Property  Southwest Hills
# 4                           NaN  17-X4748982      Property  Southwest Hills
# 5  5400 BLOCK OF NE MALLORY AVE    17-900129      Property             King
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
# 5                  1   11/28/10          11/1/10        1612
#
# ...

# %%
df.tail()
# Out:
#                             Address Case Number Crime Against   Neighborhood  \
# 41027   8800 BLOCK OF NE SANDY BLVD   17-285386       Society         Sumner
# 41028     9700 BLOCK OF SE STARK ST   17-286082       Society      Hazelwood
# 41029     9700 BLOCK OF SE STARK ST   17-286413       Society      Hazelwood
# 41030               UNKNOWN ADDRESS   17-286445       Society            NaN
# 41031  8000 BLOCK OF SE POWELL BLVD   17-286659       Society  Foster-Powell
#
#        Number of Records Occur Date Occur Month Year  Occur Time  \
# 41027                  1    8/31/17           8/1/17         535
# 41028                  1    8/31/17           8/1/17        1619
# 41029                  1    8/31/17           8/1/17        1959
# 41030                  1    8/31/17           8/1/17        2021
# 41031                  1    8/31/17           8/1/17        2354
#
#              Offense Category  Offense Count              Offense Type  \
# ...

# %%
df.head(1)
# Out:
#   Address  Case Number Crime Against Neighborhood  Number of Records  \
# 0     NaN  17-X4762181        Person          NaN                  1
#
#   Occur Date Occur Month Year  Occur Time Offense Category  Offense Count  \
# 0     1/1/96           1/1/96         800     Sex Offenses              1
#
#   Offense Type  Open Data Lat  Open Data Lon  Open Data X  Open Data Y  \
# 0         Rape            NaN            NaN          NaN          NaN
#
#   Report Date Report Month Year
# 0     1/26/17            1/1/17

# %%
df.shape
# Out:
# (41032, 17)

# %%
df.shape
# Out:
# (41032, 17)

# %% [markdown]
# # Now When count is used to get the all list of the columns titles. Some is missing but that is how we see them via .count() method.  jupyter

# %%
df.count()
# Out:
# Address              37365
# Case Number          41032
# Crime Against        41032
# Neighborhood         39712
# Number of Records    41032
# Occur Date           41032
# Occur Month Year     41032
# Occur Time           41032
# Offense Category     41032
# Offense Count        41032
# Offense Type         41032
# Open Data Lat        36712
# Open Data Lon        36712
# Open Data X          36712
# Open Data Y          36712
# Report Date          41032
# Report Month Year    41032
# dtype: int64

# %%
df.dropna().shape
# Out:
# (36146, 17)

# %% [markdown]
# NOTE : df.dropna() Dropna: it is dropping all NaN (Not a Number)

# %%
df
# Out:
#                             Address  Case Number Crime Against  \
# 0                               NaN  17-X4762181        Person
# 1                               NaN  17-X4757824      Property
# 2          200 BLOCK OF SE 78TH AVE    17-900367      Property
# 3                               NaN  17-X4748982      Property
# 4                               NaN  17-X4748982      Property
# ...                             ...          ...           ...
# 41027   8800 BLOCK OF NE SANDY BLVD    17-285386       Society
# 41028     9700 BLOCK OF SE STARK ST    17-286082       Society
# 41029     9700 BLOCK OF SE STARK ST    17-286413       Society
# 41030               UNKNOWN ADDRESS    17-286445       Society
# 41031  8000 BLOCK OF SE POWELL BLVD    17-286659       Society
#
#           Neighborhood  Number of Records Occur Date Occur Month Year  \
# 0                  NaN                  1     1/1/96           1/1/96
# ...

# %%
df.head()
# Out:
#                     Address  Case Number Crime Against     Neighborhood  \
# 0                       NaN  17-X4762181        Person              NaN
# 1                       NaN  17-X4757824      Property       Centennial
# 2  200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                       NaN  17-X4748982      Property  Southwest Hills
# 4                       NaN  17-X4748982      Property  Southwest Hills
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
#
#    Offense Category  Offense Count                             Offense Type  \
# 0      Sex Offenses              1                                     Rape
# ...

# %%
df
# Out:
#                             Address  Case Number Crime Against  \
# 0                               NaN  17-X4762181        Person
# 1                               NaN  17-X4757824      Property
# 2          200 BLOCK OF SE 78TH AVE    17-900367      Property
# 3                               NaN  17-X4748982      Property
# 4                               NaN  17-X4748982      Property
# ...                             ...          ...           ...
# 41027   8800 BLOCK OF NE SANDY BLVD    17-285386       Society
# 41028     9700 BLOCK OF SE STARK ST    17-286082       Society
# 41029     9700 BLOCK OF SE STARK ST    17-286413       Society
# 41030               UNKNOWN ADDRESS    17-286445       Society
# 41031  8000 BLOCK OF SE POWELL BLVD    17-286659       Society
#
#           Neighborhood  Number of Records Occur Date Occur Month Year  \
# 0                  NaN                  1     1/1/96           1/1/96
# ...

# %%
df['offense_count'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/portland_crime-N2QjCttf/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'offense_count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-7674effcd070> in <module>
# ...
